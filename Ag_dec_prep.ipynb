# %%
import pandas as pd
File = pd.read_csv("Nexus.xls")
Nexus = pd.DataFrame(File)
Nexus.columns
# Out:
# Index(['Timestamp', 'Form ID', 'Respondent's Name', 'Municipality/VDC', 'Ward',
#        'Sex', 'Age', 'Number of Family members', 'Educational Qualification',
#        'Primary Occupation', 'Caste',
#        '1. What sources of water does your household depend upon to fulfill irrigation needs?',
#        '2. Do you utilize most of your water endowment in fulfilling irrigation needs?',
#        ' 3. Is your household dependent on fossil fuel (diesel pump) or electrical energy for drawing water for fulfilling irrigation needs? ',
#        '4. If yes, please tick the sources of water that require energy to be conducted?',
#        '5.  Do your sources provide sufficient water to specifically fulfill your irrigation needs? ',
#        '6.  If no, what factors are responsible for causing water stress for fulfilling irrigation needs.',
#        '7. Have you observed drop in agriculture productivity during years of insufficient water availability?',
#        '8. If yes, How has insufficiency of water availability affected agricultural productivity? ',
#        '9. What adaptation measures have you adapted to ensure crop productivity amid insufficiency of water availability? ',
#        '10.   Do you rely on forest and rangeland products (such as litter or traditional biomass) to supply input fertilizers for your farming plot? ',
#        '11.    Does such collected litter or traditional biomass fulfill your need of fertilizer ?  ',
#        '12. Does litter and traditional biomass as agricultural inputs ensure optimum agricultural productivity of your farming plot?',
#        '13.  Do you manage to collect sufficient amount of litter and traditional biomass that you require?    ',
#        '14. If no, what factors have denied you from gathering sufficient amount of litter and traditional biomass? ',
#        '15.  Have you adopted adaptive measures to fulfill your agricultural input needs amid unavailability of sufficient forest-based litter and traditional biomass? ',
#        '16.  Is your farm plots close to the local forest or rangeland? ',
#        '17. Observed Positive Impact [Benefit from pollinators]',
#        '17. IObserved Positive Impact [Preservation of soil integrity from erosion and loss]',
#        '17.Observed Positive Impact [Improved soil fertility due to forest-based traditional biomass]',
#        '17. Observed Positive Impact [Preservation of soil moisture of farms at all times]',
#        '17. Observed Positive Impact [Others]',
#        '17. Observed Negative Impact [Higher wildlife intrusion damaging crops]',
#        '17. Observed Negative Impact [Crops become vulnerable to infestation by pests and insects]',
#        '17. Observed Negative Impact [Farm lands become vulnerable to forest fire]',
#        '17. Observed Negative Impact [Others]',
#        '18. What practices have you implemented to limit or adapt to the discussed disservices generated by forests or rangelands on your farm plots?',
#        '19.  Does wildlife intrude your farm plots and destroy crops?  ',
#        '20. Please specify the kind of wildlife animals that usually intrude on your farm plots and destroy crops',
#        '21. How much does wildlife cause loss to your crops in terms of estimated amount?',
#        '22. What measures have you employed to avert intrusion by wildlife in your farm plots?  ',
#        '23.  Which of the measures that you have applied have remained most successful in averting the wildlife intrusion problem?',
#        '24.   Please enlist the species of crops that you grow in your field plots and classify whether it falls under local indigenous species or imported crops (I= indigenous, H= hybrid)',
#        '25.  Please specify your reason behind adoption of imported or commercial crop species if applicable',
#        '26. Comparative advantage between Indigenous and Imported hybrid crops in terms of [Productivity per unit of land]',
#        '26. Comparative advantage between Indigenous and Imported hybrid crops in terms of  [Possibility to plant across years]',
#        '26. Comparative advantage between Indigenous and Imported hybrid crops in terms of  [Aesthetically good-looking]',
#        '26. Comparative advantage between Indigenous and Imported hybrid crops in terms of  [Vulnerability to pests]',
#        '26.  Comparative advantage between Indigenous and Imported hybrid crops in terms of  [Vulnerability to damage by wildlife]',
#        '26.  Comparative advantage between Indigenous and Imported hybrid crops in terms of  [Suitable to local biodiversity and pollinators]',
#        '26.  Comparative advantage between Indigenous and Imported hybrid crops in terms of  [More amount of fertilizers and pesticide necessary]',
#        '26. Comparative advantage between Indigenous and Imported hybrid crops in terms of  [More amount of water necessary]',
#        '26. Comparative advantage between Indigenous and Imported hybrid crops in terms of  [Adverse impact to soil health and productivity]',
#        '26. Comparative advantage between Indigenous and Imported hybrid crops in terms of  [Less amount of time and energy necessary]',
#        '26.Comparative advantage between Indigenous and Imported hybrid crops in terms of [Overall climate suitability]',
#        '26.Comparative advantage between Indigenous and Imported hybrid crops in terms of  [Initial costliness]',
#        '26.Comparative advantage between Indigenous and Imported hybrid crops in terms of  [Economic or market viability/demand]',
#        '26.Comparative advantage between Indigenous and Imported hybrid crops in terms of [Less perishable and higher storage life]',
#        '26.Comparative advantage between Indigenous and Imported hybrid crops in terms of  [Others (please specify)]',
#        '27.  Have you observed dependency on imported cereal/cash crop to have caused gradual conversion of forest and rangeland resources into agricultural fields in your community? ',
#        '28.  Have you observed unwanted introduction and intrusion of alien legumes and shrub species in your household farm plots? ',
#        '29.  Do you recall any past event concerning crop cycle that had caused introduction of such alien legumes and shrub species? Please explain',
#        '30.  Please list the names of such intruding plant species',
#        '31.  Have you observed similar unwanted species to have also intruded local forests and rangelands?',
#        '32. If yes, Please lists out the negative impacts of invasive species. [No effect]',
#        '32. If yes, Please lists out the negative impacts of invasive species. [Affected biodiversity and indigenous plant species]',
#        '32. If yes, Please lists out the negative impacts of invasive species. [Loss of usable litter and biomass availability]',
#        '32. If yes, Please lists out the negative impacts of invasive species. [Loss of groundwater conduction ability]',
#        '32. If yes, Please lists out the negative impacts of invasive species. [Increased morbidity and mortality of domestic animals]',
#        '32. If yes, Please lists out the negative impacts of invasive species. [Reduce agricultural production]',
#        '32.If yes, Please lists out the negative impacts of invasive species. [Others]',
#        '32. If yes, Please lists out the positive  impacts of invasive species. [No effect]',
#        '32. If yes, Please lists out the positive  impacts of invasive species. [Increased availability of fodder for cattle]',
#        '32.If yes, Please lists out the positive  impacts of invasive species. [Increased access to medicinal herbs]',
#        '32. If yes, Please lists out the positive  impacts of invasive species. . [Increased availability of litter to produce manure]',
#        '33.  What kind of below-mentioned practice is relevant to your farm plot?  [Others]',
#        '33.  What kind of below-mentioned practice is relevant to your farm plot?  [Chemical fertilizer Only]',
#        '33.  What kind of below-mentioned practice is relevant to your farm plot?  [Traditional biomass manure only]',
#        '33.  What kind of below-mentioned practice is relevant to your farm plot?  [Mix of chemical and biomass-based fertilizer]',
#        '34.  Have you integrated trees & shrubs in your farm plots? ',
#        '35.  Which species type of trees or shrubs have you planted in your integrated farm plot? Please explain their e and type. (N= native, I= Introduced)',
#        '36.  Please explain your reasons behind it',
#        '37.  Has agroforestry reduced your dependency on forests and rangelands for gathering fodder and forage?  ',
#        '38. What energy source do you utilize for fulfilling the following energy needs? [Cooking and water boiling]',
#        '38. What energy source do you utilize for fulfilling the following energy needs? [Space heating]',
#        '38.What energy source do you utilize for fulfilling the following energy needs? [Lighting purpose]',
#        '38. What energy source do you utilize for fulfilling the following energy needs? [Running household appliances and utilities]',
#        '38. What energy source do you utilize for fulfilling the following energy needs? [Running commercial and industrial machineries]',
#        '38. What energy source do you utilize for fulfilling the following energy needs? [Pumping or conducting water]',
#        '38. What energy source do you utilize for fulfilling the following energy needs? [Crop processing and milling]',
#        '38. What energy source do you utilize for fulfilling the following energy needs? [Others]',
#        '39. Do you observe or realize thinning availability of fuelwood and traditional biomass due to harvesting of fuelwood?',
#        '40.  Are you willing to transit to cleaner and convenient source of energy if feasible? ',
#        '41.  Do you own or have access to cleaner and convenient source of energy that you have not used or used only partially? ',
#        '42.  What constraints or compulsions has kept you from transitioning towards cleaner and convenient source of energy?',
#        '43.  Had you started collecting lesser amount of fuelwoods and traditional biomass following your adoption of cleaner and convenient source of energy for fulfilling energy needs?',
#        '44.  If no, how have you started utilizing the fuelwood and traditional biomass after you have stopped depending on them for fulfilling energy needs? ',
#        '45. Additional information'],
#       dtype='object')

# %%
#Stripping end of the phrase whitespace in column names
Colls = list(Nexus)
Colls = [x.strip() for x in Colls]
Nexus.columns = Colls
Nexus.columns
# Out:
# Index(['Timestamp', 'Form ID', 'Respondent's Name', 'Municipality/VDC', 'Ward',
#        'Sex', 'Age', 'Number of Family members', 'Educational Qualification',
#        'Primary Occupation', 'Caste',
#        '1. What sources of water does your household depend upon to fulfill irrigation needs?',
#        '2. Do you utilize most of your water endowment in fulfilling irrigation needs?',
#        '3. Is your household dependent on fossil fuel (diesel pump) or electrical energy for drawing water for fulfilling irrigation needs?',
#        '4. If yes, please tick the sources of water that require energy to be conducted?',
#        '5.  Do your sources provide sufficient water to specifically fulfill your irrigation needs?',
#        '6.  If no, what factors are responsible for causing water stress for fulfilling irrigation needs.',
#        '7. Have you observed drop in agriculture productivity during years of insufficient water availability?',
#        '8. If yes, How has insufficiency of water availability affected agricultural productivity?',
#        '9. What adaptation measures have you adapted to ensure crop productivity amid insufficiency of water availability?',
#        '10.   Do you rely on forest and rangeland products (such as litter or traditional biomass) to supply input fertilizers for your farming plot?',
#        '11.    Does such collected litter or traditional biomass fulfill your need of fertilizer ?',
#        '12. Does litter and traditional biomass as agricultural inputs ensure optimum agricultural productivity of your farming plot?',
#        '13.  Do you manage to collect sufficient amount of litter and traditional biomass that you require?',
#        '14. If no, what factors have denied you from gathering sufficient amount of litter and traditional biomass?',
#        '15.  Have you adopted adaptive measures to fulfill your agricultural input needs amid unavailability of sufficient forest-based litter and traditional biomass?',
#        '16.  Is your farm plots close to the local forest or rangeland?',
#        '17. Observed Positive Impact [Benefit from pollinators]',
#        '17. IObserved Positive Impact [Preservation of soil integrity from erosion and loss]',
#        '17.Observed Positive Impact [Improved soil fertility due to forest-based traditional biomass]',
#        '17. Observed Positive Impact [Preservation of soil moisture of farms at all times]',
#        '17. Observed Positive Impact [Others]',
#        '17. Observed Negative Impact [Higher wildlife intrusion damaging crops]',
#        '17. Observed Negative Impact [Crops become vulnerable to infestation by pests and insects]',
#        '17. Observed Negative Impact [Farm lands become vulnerable to forest fire]',
#        '17. Observed Negative Impact [Others]',
#        '18. What practices have you implemented to limit or adapt to the discussed disservices generated by forests or rangelands on your farm plots?',
#        '19.  Does wildlife intrude your farm plots and destroy crops?',
#        '20. Please specify the kind of wildlife animals that usually intrude on your farm plots and destroy crops',
#        '21. How much does wildlife cause loss to your crops in terms of estimated amount?',
#        '22. What measures have you employed to avert intrusion by wildlife in your farm plots?',
#        '23.  Which of the measures that you have applied have remained most successful in averting the wildlife intrusion problem?',
#        '24.   Please enlist the species of crops that you grow in your field plots and classify whether it falls under local indigenous species or imported crops (I= indigenous, H= hybrid)',
#        '25.  Please specify your reason behind adoption of imported or commercial crop species if applicable',
#        '26. Comparative advantage between Indigenous and Imported hybrid crops in terms of [Productivity per unit of land]',
#        '26. Comparative advantage between Indigenous and Imported hybrid crops in terms of  [Possibility to plant across years]',
#        '26. Comparative advantage between Indigenous and Imported hybrid crops in terms of  [Aesthetically good-looking]',
#        '26. Comparative advantage between Indigenous and Imported hybrid crops in terms of  [Vulnerability to pests]',
#        '26.  Comparative advantage between Indigenous and Imported hybrid crops in terms of  [Vulnerability to damage by wildlife]',
#        '26.  Comparative advantage between Indigenous and Imported hybrid crops in terms of  [Suitable to local biodiversity and pollinators]',
#        '26.  Comparative advantage between Indigenous and Imported hybrid crops in terms of  [More amount of fertilizers and pesticide necessary]',
#        '26. Comparative advantage between Indigenous and Imported hybrid crops in terms of  [More amount of water necessary]',
#        '26. Comparative advantage between Indigenous and Imported hybrid crops in terms of  [Adverse impact to soil health and productivity]',
#        '26. Comparative advantage between Indigenous and Imported hybrid crops in terms of  [Less amount of time and energy necessary]',
#        '26.Comparative advantage between Indigenous and Imported hybrid crops in terms of [Overall climate suitability]',
#        '26.Comparative advantage between Indigenous and Imported hybrid crops in terms of  [Initial costliness]',
#        '26.Comparative advantage between Indigenous and Imported hybrid crops in terms of  [Economic or market viability/demand]',
#        '26.Comparative advantage between Indigenous and Imported hybrid crops in terms of [Less perishable and higher storage life]',
#        '26.Comparative advantage between Indigenous and Imported hybrid crops in terms of  [Others (please specify)]',
#        '27.  Have you observed dependency on imported cereal/cash crop to have caused gradual conversion of forest and rangeland resources into agricultural fields in your community?',
#        '28.  Have you observed unwanted introduction and intrusion of alien legumes and shrub species in your household farm plots?',
#        '29.  Do you recall any past event concerning crop cycle that had caused introduction of such alien legumes and shrub species? Please explain',
#        '30.  Please list the names of such intruding plant species',
#        '31.  Have you observed similar unwanted species to have also intruded local forests and rangelands?',
#        '32. If yes, Please lists out the negative impacts of invasive species. [No effect]',
#        '32. If yes, Please lists out the negative impacts of invasive species. [Affected biodiversity and indigenous plant species]',
#        '32. If yes, Please lists out the negative impacts of invasive species. [Loss of usable litter and biomass availability]',
#        '32. If yes, Please lists out the negative impacts of invasive species. [Loss of groundwater conduction ability]',
#        '32. If yes, Please lists out the negative impacts of invasive species. [Increased morbidity and mortality of domestic animals]',
#        '32. If yes, Please lists out the negative impacts of invasive species. [Reduce agricultural production]',
#        '32.If yes, Please lists out the negative impacts of invasive species. [Others]',
#        '32. If yes, Please lists out the positive  impacts of invasive species. [No effect]',
#        '32. If yes, Please lists out the positive  impacts of invasive species. [Increased availability of fodder for cattle]',
#        '32.If yes, Please lists out the positive  impacts of invasive species. [Increased access to medicinal herbs]',
#        '32. If yes, Please lists out the positive  impacts of invasive species. . [Increased availability of litter to produce manure]',
#        '33.  What kind of below-mentioned practice is relevant to your farm plot?  [Others]',
#        '33.  What kind of below-mentioned practice is relevant to your farm plot?  [Chemical fertilizer Only]',
#        '33.  What kind of below-mentioned practice is relevant to your farm plot?  [Traditional biomass manure only]',
#        '33.  What kind of below-mentioned practice is relevant to your farm plot?  [Mix of chemical and biomass-based fertilizer]',
#        '34.  Have you integrated trees & shrubs in your farm plots?',
#        '35.  Which species type of trees or shrubs have you planted in your integrated farm plot? Please explain their e and type. (N= native, I= Introduced)',
#        '36.  Please explain your reasons behind it',
#        '37.  Has agroforestry reduced your dependency on forests and rangelands for gathering fodder and forage?',
#        '38. What energy source do you utilize for fulfilling the following energy needs? [Cooking and water boiling]',
#        '38. What energy source do you utilize for fulfilling the following energy needs? [Space heating]',
#        '38.What energy source do you utilize for fulfilling the following energy needs? [Lighting purpose]',
#        '38. What energy source do you utilize for fulfilling the following energy needs? [Running household appliances and utilities]',
#        '38. What energy source do you utilize for fulfilling the following energy needs? [Running commercial and industrial machineries]',
#        '38. What energy source do you utilize for fulfilling the following energy needs? [Pumping or conducting water]',
#        '38. What energy source do you utilize for fulfilling the following energy needs? [Crop processing and milling]',
#        '38. What energy source do you utilize for fulfilling the following energy needs? [Others]',
#        '39. Do you observe or realize thinning availability of fuelwood and traditional biomass due to harvesting of fuelwood?',
#        '40.  Are you willing to transit to cleaner and convenient source of energy if feasible?',
#        '41.  Do you own or have access to cleaner and convenient source of energy that you have not used or used only partially?',
#        '42.  What constraints or compulsions has kept you from transitioning towards cleaner and convenient source of energy?',
#        '43.  Had you started collecting lesser amount of fuelwoods and traditional biomass following your adoption of cleaner and convenient source of energy for fulfilling energy needs?',
#        '44.  If no, how have you started utilizing the fuelwood and traditional biomass after you have stopped depending on them for fulfilling energy needs?',
#        '45. Additional information'],
#       dtype='object')

# %%
#saving the whitespace stripped version of the Nexus csv for future use
Nexus.to_csv("Nexus_strip.csv")

# %%
# Indexing the column names to crop the columns of choice
for i, columns in enumerate(Colls):
    print(i, columns)
# Out:
# 0 Timestamp
# 1 Form ID
# 2 Respondent's Name
# 3 Municipality/VDC
# 4 Ward
# 5 Sex
# 6 Age
# 7 Number of Family members
# 8 Educational Qualification
# 9 Primary Occupation
# 10 Caste
# 11 1. What sources of water does your household depend upon to fulfill irrigation needs?
# 12 2. Do you utilize most of your water endowment in fulfilling irrigation needs?
# 13 3. Is your household dependent on fossil fuel (diesel pump) or electrical energy for drawing water for fulfilling irrigation needs?
# 14 4. If yes, please tick the sources of water that require energy to be conducted?
# 15 5.  Do your sources provide sufficient water to specifically fulfill your irrigation needs?
# 16 6.  If no, what factors are responsible for causing water stress for fulfilling irrigation needs.
# 17 7. Have you observed drop in agriculture productivity during years of insufficient water availability?
# 18 8. If yes, How has insufficiency of water availability affected agricultural productivity?
# 19 9. What adaptation measures have you adapted to ensure crop productivity amid insufficiency of water availability?
# 20 10.   Do you rely on forest and rangeland products (such as litter or traditional biomass) to supply input fertilizers for your farming plot?
# 21 11.    Does such collected litter or traditional biomass fulfill your need of fertilizer ?
# 22 12. Does litter and traditional biomass as agricultural inputs ensure optimum agricultural productivity of your farming plot?
# 23 13.  Do you manage to collect sufficient amount of litter and traditional biomass that you require?
# 24 14. If no, what factors have denied you from gathering sufficient amount of litter and traditional biomass?
# 25 15.  Have you adopted adaptive measures to fulfill your agricultural input needs amid unavailability of sufficient forest-based litter and traditional biomass?
# 26 16.  Is your farm plots close to the local forest or rangeland?
# 27 17. Observed Positive Impact [Benefit from pollinators]
# 28 17. IObserved Positive Impact [Preservation of soil integrity from erosion and loss]
# 29 17.Observed Positive Impact [Improved soil fertility due to forest-based traditional biomass]
# 30 17. Observed Positive Impact [Preservation of soil moisture of farms at all times]
# 31 17. Observed Positive Impact [Others]
# 32 17. Observed Negative Impact [Higher wildlife intrusion damaging crops]
# 33 17. Observed Negative Impact [Crops become vulnerable to infestation by pests and insects]
# 34 17. Observed Negative Impact [Farm lands become vulnerable to forest fire]
# 35 17. Observed Negative Impact [Others]
# 36 18. What practices have you implemented to limit or adapt to the discussed disservices generated by forests or rangelands on your farm plots?
# 37 19.  Does wildlife intrude your farm plots and destroy crops?
# 38 20. Please specify the kind of wildlife animals that usually intrude on your farm plots and destroy crops
# 39 21. How much does wildlife cause loss to your crops in terms of estimated amount?
# 40 22. What measures have you employed to avert intrusion by wildlife in your farm plots?
# 41 23.  Which of the measures that you have applied have remained most successful in averting the wildlife intrusion problem?
# 42 24.   Please enlist the species of crops that you grow in your field plots and classify whether it falls under local indigenous species or imported crops (I= indigenous, H= hybrid)
# 43 25.  Please specify your reason behind adoption of imported or commercial crop species if applicable
# 44 26. Comparative advantage between Indigenous and Imported hybrid crops in terms of [Productivity per unit of land]
# 45 26. Comparative advantage between Indigenous and Imported hybrid crops in terms of  [Possibility to plant across years]
# 46 26. Comparative advantage between Indigenous and Imported hybrid crops in terms of  [Aesthetically good-looking]
# 47 26. Comparative advantage between Indigenous and Imported hybrid crops in terms of  [Vulnerability to pests]
# 48 26.  Comparative advantage between Indigenous and Imported hybrid crops in terms of  [Vulnerability to damage by wildlife]
# 49 26.  Comparative advantage between Indigenous and Imported hybrid crops in terms of  [Suitable to local biodiversity and pollinators]
# 50 26.  Comparative advantage between Indigenous and Imported hybrid crops in terms of  [More amount of fertilizers and pesticide necessary]
# 51 26. Comparative advantage between Indigenous and Imported hybrid crops in terms of  [More amount of water necessary]
# 52 26. Comparative advantage between Indigenous and Imported hybrid crops in terms of  [Adverse impact to soil health and productivity]
# 53 26. Comparative advantage between Indigenous and Imported hybrid crops in terms of  [Less amount of time and energy necessary]
# 54 26.Comparative advantage between Indigenous and Imported hybrid crops in terms of [Overall climate suitability]
# 55 26.Comparative advantage between Indigenous and Imported hybrid crops in terms of  [Initial costliness]
# 56 26.Comparative advantage between Indigenous and Imported hybrid crops in terms of  [Economic or market viability/demand]
# 57 26.Comparative advantage between Indigenous and Imported hybrid crops in terms of [Less perishable and higher storage life]
# 58 26.Comparative advantage between Indigenous and Imported hybrid crops in terms of  [Others (please specify)]
# 59 27.  Have you observed dependency on imported cereal/cash crop to have caused gradual conversion of forest and rangeland resources into agricultural fields in your community?
# 60 28.  Have you observed unwanted introduction and intrusion of alien legumes and shrub species in your household farm plots?
# 61 29.  Do you recall any past event concerning crop cycle that had caused introduction of such alien legumes and shrub species? Please explain
# 62 30.  Please list the names of such intruding plant species
# 63 31.  Have you observed similar unwanted species to have also intruded local forests and rangelands?
# 64 32. If yes, Please lists out the negative impacts of invasive species. [No effect]
# 65 32. If yes, Please lists out the negative impacts of invasive species. [Affected biodiversity and indigenous plant species]
# 66 32. If yes, Please lists out the negative impacts of invasive species. [Loss of usable litter and biomass availability]
# 67 32. If yes, Please lists out the negative impacts of invasive species. [Loss of groundwater conduction ability]
# 68 32. If yes, Please lists out the negative impacts of invasive species. [Increased morbidity and mortality of domestic animals]
# 69 32. If yes, Please lists out the negative impacts of invasive species. [Reduce agricultural production]
# 70 32.If yes, Please lists out the negative impacts of invasive species. [Others]
# 71 32. If yes, Please lists out the positive  impacts of invasive species. [No effect]
# 72 32. If yes, Please lists out the positive  impacts of invasive species. [Increased availability of fodder for cattle]
# 73 32.If yes, Please lists out the positive  impacts of invasive species. [Increased access to medicinal herbs]
# 74 32. If yes, Please lists out the positive  impacts of invasive species. . [Increased availability of litter to produce manure]
# 75 33.  What kind of below-mentioned practice is relevant to your farm plot?  [Others]
# 76 33.  What kind of below-mentioned practice is relevant to your farm plot?  [Chemical fertilizer Only]
# 77 33.  What kind of below-mentioned practice is relevant to your farm plot?  [Traditional biomass manure only]
# 78 33.  What kind of below-mentioned practice is relevant to your farm plot?  [Mix of chemical and biomass-based fertilizer]
# 79 34.  Have you integrated trees & shrubs in your farm plots?
# 80 35.  Which species type of trees or shrubs have you planted in your integrated farm plot? Please explain their e and type. (N= native, I= Introduced)
# 81 36.  Please explain your reasons behind it
# 82 37.  Has agroforestry reduced your dependency on forests and rangelands for gathering fodder and forage?
# 83 38. What energy source do you utilize for fulfilling the following energy needs? [Cooking and water boiling]
# 84 38. What energy source do you utilize for fulfilling the following energy needs? [Space heating]
# 85 38.What energy source do you utilize for fulfilling the following energy needs? [Lighting purpose]
# 86 38. What energy source do you utilize for fulfilling the following energy needs? [Running household appliances and utilities]
# 87 38. What energy source do you utilize for fulfilling the following energy needs? [Running commercial and industrial machineries]
# 88 38. What energy source do you utilize for fulfilling the following energy needs? [Pumping or conducting water]
# 89 38. What energy source do you utilize for fulfilling the following energy needs? [Crop processing and milling]
# 90 38. What energy source do you utilize for fulfilling the following energy needs? [Others]
# 91 39. Do you observe or realize thinning availability of fuelwood and traditional biomass due to harvesting of fuelwood?
# 92 40.  Are you willing to transit to cleaner and convenient source of energy if feasible?
# 93 41.  Do you own or have access to cleaner and convenient source of energy that you have not used or used only partially?
# 94 42.  What constraints or compulsions has kept you from transitioning towards cleaner and convenient source of energy?
# 95 43.  Had you started collecting lesser amount of fuelwoods and traditional biomass following your adoption of cleaner and convenient source of energy for fulfilling energy needs?
# 96 44.  If no, how have you started utilizing the fuelwood and traditional biomass after you have stopped depending on them for fulfilling energy needs?
# 97 45. Additional information

# %%
#Able to look through the columns in the Nexus as a result of scrollable result privelege
Personal = Nexus.iloc[:, 2:11]
HVI = Nexus.iloc[:, 44:59]
HVI.columns
# Out:
# Index(['26. Comparative advantage between Indigenous and Imported hybrid crops in terms of [Productivity per unit of land]',
#        '26. Comparative advantage between Indigenous and Imported hybrid crops in terms of  [Possibility to plant across years]',
#        '26. Comparative advantage between Indigenous and Imported hybrid crops in terms of  [Aesthetically good-looking]',
#        '26. Comparative advantage between Indigenous and Imported hybrid crops in terms of  [Vulnerability to pests]',
#        '26.  Comparative advantage between Indigenous and Imported hybrid crops in terms of  [Vulnerability to damage by wildlife]',
#        '26.  Comparative advantage between Indigenous and Imported hybrid crops in terms of  [Suitable to local biodiversity and pollinators]',
#        '26.  Comparative advantage between Indigenous and Imported hybrid crops in terms of  [More amount of fertilizers and pesticide necessary]',
#        '26. Comparative advantage between Indigenous and Imported hybrid crops in terms of  [More amount of water necessary]',
#        '26. Comparative advantage between Indigenous and Imported hybrid crops in terms of  [Adverse impact to soil health and productivity]',
#        '26. Comparative advantage between Indigenous and Imported hybrid crops in terms of  [Less amount of time and energy necessary]',
#        '26.Comparative advantage between Indigenous and Imported hybrid crops in terms of [Overall climate suitability]',
#        '26.Comparative advantage between Indigenous and Imported hybrid crops in terms of  [Initial costliness]',
#        '26.Comparative advantage between Indigenous and Imported hybrid crops in terms of  [Economic or market viability/demand]',
#        '26.Comparative advantage between Indigenous and Imported hybrid crops in terms of [Less perishable and higher storage life]',
#        '26.Comparative advantage between Indigenous and Imported hybrid crops in terms of  [Others (please specify)]'],
#       dtype='object')

# %% [markdown]
# ### Working with the Personal Sociodemographic data

# %%
#First we wrangle with the personal dataframe
Personal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Respondent's Name          118 non-null    object
#  1   Municipality/VDC           118 non-null    object
#  2   Ward                       116 non-null    float64
#  3   Sex                        117 non-null    object
#  4   Age                        115 non-null    float64
#  5   Number of Family members   115 non-null    float64
#  6   Educational Qualification  117 non-null    object
#  7   Primary Occupation         116 non-null    object
#  8   Caste                      117 non-null    object
# dtypes: float64(3), object(6)
# memory usage: 8.4+ KB

# %%
#Quick checking the value types
Personal["Municipality/VDC"].value_counts()
# Out:
# Municipality/VDC
# Bheriganga (Surkhet)    43
# Budhinanda (Bajura)     41
# Bhairabi (Dailekh)      27
# Bhairabi                 4
# Bhairabi(Dailekh)        3
# Name: count, dtype: int64

# %%
#It appears we need to reclassify the location into three areas
Personal["Municipality/VDC"].replace(["Bhairabi", "Bhairabi(Dailekh)"], "Bhairabi (Dailekh)", inplace = True)
Personal["Municipality/VDC"].value_counts()
# Out:
# C:\Users\prien\AppData\Local\Temp\ipykernel_15312\3616938029.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Personal["Municipality/VDC"].replace(["Bhairabi", "Bhairabi(Dailekh)"], "Bhairabi (Dailekh)", inplace = True)
# Municipality/VDC
# Bheriganga (Surkhet)    43
# Budhinanda (Bajura)     41
# Bhairabi (Dailekh)      34
# Name: count, dtype: int64

# %%
#we need to rename the Municipality column properly
Personal.rename(columns = {"Municipality/VDC": "Municipality"}, inplace = True)

# %%
#We need to reclassify the Educational Qualifications into more neater bins
Personal["Educational Qualification"].replace(["10 class", "12 class", "11 class", "Grade 12"], "Higher Secondary", inplace = True)
Personal["Educational Qualification"].replace("Illiterate", "Unofficial Education", inplace=True)
Personal["Educational Qualification"].replace("Grade 10", "Higher Secondary", inplace = True)
Personal["Educational Qualification"].replace(["8 class","4 class", "6 class", "5 class"], "Lower Secondary", inplace = True) 
Personal["Educational Qualification"].value_counts()
# Out:
# C:\Users\prien\AppData\Local\Temp\ipykernel_15312\2319836824.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Personal["Educational Qualification"].replace(["10 class", "12 class", "11 class", "Grade 12"], "Higher Secondary", inplace = True)
# Educational Qualification
# Unofficial Education    81
# Higher Secondary        26
# Lower Secondary          5
# Undergraduate            4
# Graduation               1
# Name: count, dtype: int64

# %%
#Saving our post-wrangled dataframe with sociodemographic variables for future use
Personal.info()
Personal.to_csv("Personal.csv")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Respondent's Name          118 non-null    object
#  1   Municipality               118 non-null    object
#  2   Ward                       116 non-null    float64
#  3   Sex                        117 non-null    object
#  4   Age                        115 non-null    float64
#  5   Number of Family members   115 non-null    float64
#  6   Educational Qualification  117 non-null    object
#  7   Primary Occupation         116 non-null    object
#  8   Caste                      117 non-null    object
# dtypes: float64(3), object(6)
# memory usage: 8.4+ KB

# %% [markdown]
# #### Working to prepare the Target variable

# %%
Target = Nexus.iloc[:, 75:79]
Target.columns
# Out:
# Index(['33.  What kind of below-mentioned practice is relevant to your farm plot?  [Others]',
#        '33.  What kind of below-mentioned practice is relevant to your farm plot?  [Chemical fertilizer Only]',
#        '33.  What kind of below-mentioned practice is relevant to your farm plot?  [Traditional biomass manure only]',
#        '33.  What kind of below-mentioned practice is relevant to your farm plot?  [Mix of chemical and biomass-based fertilizer]'],
#       dtype='object')

# %%
Target = Target.rename(columns = {
    "33.  What kind of below-mentioned practice is relevant to your farm plot?  [Others]": "Crop Choice 1",
    "33.  What kind of below-mentioned practice is relevant to your farm plot?  [Chemical fertilizer Only]": "Crop Choice 2",
    "33.  What kind of below-mentioned practice is relevant to your farm plot?  [Traditional biomass manure only]": "Crop Choice 3", 
    "33.  What kind of below-mentioned practice is relevant to your farm plot?  [Mix of chemical and biomass-based fertilizer]": "Crop Choice 4"})
Target.columns
# Out:
# Index(['Crop Choice 1', 'Crop Choice 2', 'Crop Choice 3', 'Crop Choice 4'], dtype='object')

# %%
Target.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Crop Choice 1  2 non-null      object
#  1   Crop Choice 2  3 non-null      object
#  2   Crop Choice 3  45 non-null     object
#  3   Crop Choice 4  69 non-null     object
# dtypes: object(4)
# memory usage: 3.8+ KB

# %%
Target["Crop Choice 1"].value_counts()
# Out:
# Crop Choice 1
# Positive Impact (Ability to turn the IAPs into organic insecticides)    1
# Positive Impact (Helps in groundwater recharge)                         1
# Name: count, dtype: int64

# %%
Target["Crop Choice 2"].value_counts()
# Out:
# Crop Choice 2
# Planting of indigenous species of crops only    3
# Name: count, dtype: int64

# %%
Target["Crop Choice 3"].value_counts()
# Out:
# Crop Choice 3
# Planting of mix of imported and indigenous species of crops    23
# Planting of indigenous species of crops only                   21
# Planting of imported species of crops only                      1
# Name: count, dtype: int64

# %%
Target["Crop Choice 4"].value_counts()
# Out:
# Crop Choice 4
# Planting of mix of imported and indigenous species of crops    34
# Planting of indigenous species of crops only                   27
# Planting of imported species of crops only                      8
# Name: count, dtype: int64

# %%
#So introducing the feature consolidation syntax without the others option that does not seem to be very significant
Target["Crop Choice"] = Target["Crop Choice 4"].fillna(Target["Crop Choice 2"]).fillna(Target["Crop Choice 3"])
Target["Crop Choice"].value_counts()
#Ok, now we have all values consolidated into a single feature
# Out:
# Crop Choice
# Planting of mix of imported and indigenous species of crops    57
# Planting of indigenous species of crops only                   51
# Planting of imported species of crops only                      9
# Name: count, dtype: int64

# %%
#Now, dropping the unnecessary features
Target.drop(columns = ["Crop Choice 2", "Crop Choice 3", "Crop Choice 4", "Crop Choice 1"], inplace = True)
Target.columns
# Out:
# Index(['Crop Choice'], dtype='object')

# %%
#Lets replace the word "imported" with "hybrid" for the sake of consistency with our values in the independent variales
Target["Crop Choice"].replace(["Planting of mix of imported and indigenous species of crops", "Planting of imported species of crops only"], 
                              ["Planting of mix of hybrid and indigenous species of crops", "Planting of hybrid species of crops only"], 
                              inplace = True)
Target.value_counts()
# Out:
# C:\Users\prien\AppData\Local\Temp\ipykernel_15312\4699582.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Target["Crop Choice"].replace(["Planting of mix of imported and indigenous species of crops", "Planting of imported species of crops only"],
# Crop Choice
# Planting of mix of hybrid and indigenous species of crops    57
# Planting of indigenous species of crops only                 51
# Planting of hybrid species of crops only                      9
# Name: count, dtype: int64

# %%
#Saving the Target values dataframe in a csv file for future use
Target.to_csv('Target.csv')

# %% [markdown]
# ### Working to prepare the Independent Variable representing comparative advantages of certain crop type in a given comparision field

# %%
HVI.columns
# Out:
# Index(['26. Comparative advantage between Indigenous and Imported hybrid crops in terms of [Productivity per unit of land]',
#        '26. Comparative advantage between Indigenous and Imported hybrid crops in terms of  [Possibility to plant across years]',
#        '26. Comparative advantage between Indigenous and Imported hybrid crops in terms of  [Aesthetically good-looking]',
#        '26. Comparative advantage between Indigenous and Imported hybrid crops in terms of  [Vulnerability to pests]',
#        '26.  Comparative advantage between Indigenous and Imported hybrid crops in terms of  [Vulnerability to damage by wildlife]',
#        '26.  Comparative advantage between Indigenous and Imported hybrid crops in terms of  [Suitable to local biodiversity and pollinators]',
#        '26.  Comparative advantage between Indigenous and Imported hybrid crops in terms of  [More amount of fertilizers and pesticide necessary]',
#        '26. Comparative advantage between Indigenous and Imported hybrid crops in terms of  [More amount of water necessary]',
#        '26. Comparative advantage between Indigenous and Imported hybrid crops in terms of  [Adverse impact to soil health and productivity]',
#        '26. Comparative advantage between Indigenous and Imported hybrid crops in terms of  [Less amount of time and energy necessary]',
#        '26.Comparative advantage between Indigenous and Imported hybrid crops in terms of [Overall climate suitability]',
#        '26.Comparative advantage between Indigenous and Imported hybrid crops in terms of  [Initial costliness]',
#        '26.Comparative advantage between Indigenous and Imported hybrid crops in terms of  [Economic or market viability/demand]',
#        '26.Comparative advantage between Indigenous and Imported hybrid crops in terms of [Less perishable and higher storage life]',
#        '26.Comparative advantage between Indigenous and Imported hybrid crops in terms of  [Others (please specify)]'],
#       dtype='object')

# %%
HVI.rename(columns = {"26. Comparative advantage between Indigenous and Imported hybrid crops in terms of [Productivity per unit of land]": "Productivity per unit of land",
                      "26. Comparative advantage between Indigenous and Imported hybrid crops in terms of  [Possibility to plant across years]": "Possibility to plant across years",
                      "26. Comparative advantage between Indigenous and Imported hybrid crops in terms of  [Aesthetically good-looking]": "Aesthetically good-looking", 
                      "26. Comparative advantage between Indigenous and Imported hybrid crops in terms of  [Vulnerability to pests]": "Vulnerability to pests", 
                      "26.  Comparative advantage between Indigenous and Imported hybrid crops in terms of  [Vulnerability to damage by wildlife]": "Vulnerability to damage by wildlife", 
                      "26.  Comparative advantage between Indigenous and Imported hybrid crops in terms of  [Suitable to local biodiversity and pollinators]": "Suitable to local biodiversity and pollinators", 
                      "26.  Comparative advantage between Indigenous and Imported hybrid crops in terms of  [More amount of fertilizers and pesticide necessary]": "More amount of fertilizers and pesticide necessary", 
                      "26. Comparative advantage between Indigenous and Imported hybrid crops in terms of  [More amount of water necessary]": "More amount of water necessary", 
                      "26. Comparative advantage between Indigenous and Imported hybrid crops in terms of  [Adverse impact to soil health and productivity]": "Adverse impact to soil health and productivity", 
                      "26. Comparative advantage between Indigenous and Imported hybrid crops in terms of  [Less amount of time and energy necessary]": "Less amount of time and energy necessary",
                      "26.Comparative advantage between Indigenous and Imported hybrid crops in terms of [Overall climate suitability]": "Overall climate suitability", 
                      "26.Comparative advantage between Indigenous and Imported hybrid crops in terms of  [Initial costliness]": "Initial costliness",
                      "26.Comparative advantage between Indigenous and Imported hybrid crops in terms of  [Economic or market viability/demand]": "Economic or market viability/demand", 
                      "26.Comparative advantage between Indigenous and Imported hybrid crops in terms of [Less perishable and higher storage life]": "Less perishable and higher storage life", 
                      "26.Comparative advantage between Indigenous and Imported hybrid crops in terms of  [Others (please specify)]": "Other advantages"}, 
                      inplace = True)

# %%
HVI.columns
# Out:
# Index(['Productivity per unit of land', 'Possibility to plant across years',
#        'Aesthetically good-looking', 'Vulnerability to pests',
#        'Vulnerability to damage by wildlife',
#        'Suitable to local biodiversity and pollinators',
#        'More amount of fertilizers and pesticide necessary',
#        'More amount of water necessary',
#        'Adverse impact to soil health and productivity',
#        'Less amount of time and energy necessary',
#        'Overall climate suitability', 'Initial costliness',
#        'Economic or market viability/demand',
#        'Less perishable and higher storage life', 'Other advantages'],
#       dtype='object')

# %%
HVI["Productivity per unit of land"].value_counts()
# Out:
# Productivity per unit of land
# Hybrid crop species        38
# No difference              11
# Indigenous crop species     2
# Name: count, dtype: int64

# %%
HVI["Possibility to plant across years"].value_counts()
# Out:
# Possibility to plant across years
# No difference              17
# Indigenous crop species    14
# Hybrid crop species        13
# Name: count, dtype: int64

# %%
HVI["Overall climate suitability"].value_counts()
# Out:
# Overall climate suitability
# Indigenous crop species    28
# No difference              20
# Hybrid crop species         2
# Name: count, dtype: int64

# %%
HVI["Other advantages"].value_counts()
# Out:
# Other advantages
# Taste (Indigenous crop species)                             3
# Taste (Hybrid crop species)                                 1
# Availability of seeds at the market (Indigenous species)    1
# Availability of seeds at the market (hybrid species)        1
# Name: count, dtype: int64

# %%
HVI["More amount of water necessary"].value_counts()
# Out:
# More amount of water necessary
# Hybrid crop species        44
# Indigenous crop species     9
# No difference               6
# Name: count, dtype: int64

# %%
HVI["More amount of fertilizers and pesticide necessary"].value_counts()
# Out:
# More amount of fertilizers and pesticide necessary
# Hybrid crop species        46
# No difference               9
# Indigenous crop species     4
# Name: count, dtype: int64

# %%
HVI["Less perishable and higher storage life"].value_counts()
# Out:
# Less perishable and higher storage life
# Indigenous crop species    26
# Hybrid crop species        23
# No difference               7
# Name: count, dtype: int64

# %%
HVI["Less amount of time and energy necessary"].value_counts()
# Out:
# Less amount of time and energy necessary
# Indigenous crop species    33
# Hybrid crop species        17
# No difference               8
# Name: count, dtype: int64

# %%
HVI["Initial costliness"].value_counts()
# Out:
# Initial costliness
# Hybrid crop species        36
# Indigenous crop species     9
# No difference               8
# Name: count, dtype: int64

# %%
HVI["Economic or market viability/demand"].value_counts()
# Out:
# Economic or market viability/demand
# Hybrid crop species        36
# Indigenous crop species    12
# No difference               5
# Name: count, dtype: int64

# %%
HVI["Aesthetically good-looking"].value_counts()
# Out:
# Aesthetically good-looking
# Hybrid crop species        29
# No difference              15
# Indigenous crop species     6
# Name: count, dtype: int64

# %%
HVI["Adverse impact to soil health and productivity"].value_counts()
# Out:
# Adverse impact to soil health and productivity
# Hybrid crop species        24
# No difference              23
# Indigenous crop species    10
# Name: count, dtype: int64

# %%
HVI["Vulnerability to pests"].value_counts()
# Out:
# Vulnerability to pests
# Hybrid crop species        46
# No difference               6
# Indigenous crop species     6
# Name: count, dtype: int64

# %%
HVI["Vulnerability to damage by wildlife"].value_counts()
# Out:
# Vulnerability to damage by wildlife
# No difference              26
# Indigenous crop species    22
# Hybrid crop species         8
# Name: count, dtype: int64

# %%
HVI["Suitable to local biodiversity and pollinators"].value_counts()
# Out:
# Suitable to local biodiversity and pollinators
# Indigenous crop species    24
# No difference              20
# Hybrid crop species         6
# Name: count, dtype: int64

# %%
#Lets drop the "Other Advantages" column because the values within this feature is uncomparable to values in other features
HVI.drop(columns = "Other advantages", axis=1, inplace = True)
HVI.info()
#we still need to deal with the null values spread across our features
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 14 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   Productivity per unit of land                       51 non-null     object
#  1   Possibility to plant across years                   44 non-null     object
#  2   Aesthetically good-looking                          50 non-null     object
#  3   Vulnerability to pests                              58 non-null     object
#  4   Vulnerability to damage by wildlife                 56 non-null     object
#  5   Suitable to local biodiversity and pollinators      50 non-null     object
#  6   More amount of fertilizers and pesticide necessary  59 non-null     object
#  7   More amount of water necessary                      59 non-null     object
#  8   Adverse impact to soil health and productivity      57 non-null     object
#  9   Less amount of time and energy necessary            58 non-null     object
#  10  Overall climate suitability                         50 non-null     object
#  11  Initial costliness                                  53 non-null     object
#  12  Economic or market viability/demand                 53 non-null     object
#  13  Less perishable and higher storage life             56 non-null     object
# dtypes: object(14)
# memory usage: 13.0+ KB

# %%
#Saving out dataframe of independent variables for future use
HVI.to_csv("HVI.csv")

# %% [markdown]
# #### Creating a Master Dataframe for preprocessing and analysis

# %%
#Now merging all of the dataframe for further preprocessing and analysis
Crop_decision = pd.concat([Personal, HVI, Target], axis = 1)
Crop_decision.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 24 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   Respondent's Name                                   118 non-null    object
#  1   Municipality                                        118 non-null    object
#  2   Ward                                                116 non-null    float64
#  3   Sex                                                 117 non-null    object
#  4   Age                                                 115 non-null    float64
#  5   Number of Family members                            115 non-null    float64
#  6   Educational Qualification                           117 non-null    object
#  7   Primary Occupation                                  116 non-null    object
#  8   Caste                                               117 non-null    object
#  9   Productivity per unit of land                       51 non-null     object
#  10  Possibility to plant across years                   44 non-null     object
#  11  Aesthetically good-looking                          50 non-null     object
#  12  Vulnerability to pests                              58 non-null     object
#  13  Vulnerability to damage by wildlife                 56 non-null     object
#  14  Suitable to local biodiversity and pollinators      50 non-null     object
#  15  More amount of fertilizers and pesticide necessary  59 non-null     object
#  16  More amount of water necessary                      59 non-null     object
#  17  Adverse impact to soil health and productivity      57 non-null     object
#  18  Less amount of time and energy necessary            58 non-null     object
#  19  Overall climate suitability                         50 non-null     object
#  20  Initial costliness                                  53 non-null     object
#  21  Economic or market viability/demand                 53 non-null     object
#  22  Less perishable and higher storage life             56 non-null     object
#  23  Crop Choice                                         117 non-null    object
# dtypes: float64(3), object(21)
# memory usage: 22.3+ KB

# %% [markdown]
# ##### Dropping the missing values wherever feasible

# %%
#Lets churn out the entire record based on one null data that is in our target variable
Crop_decision = Crop_decision.dropna(subset=["Crop Choice"])

# %%
#Now, let's churn out the entire record based on null data that is in our sociodemographic feature sets
Crop_decision = Crop_decision.dropna(subset=["Respondent's Name", "Municipality", "Ward", "Sex", "Age", "Number of Family members", 
                                             "Educational Qualification", "Primary Occupation", "Caste"])
Crop_decision.info()
#so we are now down with only 111 entries out of previous 118
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 111 entries, 0 to 117
# Data columns (total 24 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   Respondent's Name                                   111 non-null    object
#  1   Municipality                                        111 non-null    object
#  2   Ward                                                111 non-null    float64
#  3   Sex                                                 111 non-null    object
#  4   Age                                                 111 non-null    float64
#  5   Number of Family members                            111 non-null    float64
#  6   Educational Qualification                           111 non-null    object
#  7   Primary Occupation                                  111 non-null    object
#  8   Caste                                               111 non-null    object
#  9   Productivity per unit of land                       48 non-null     object
#  10  Possibility to plant across years                   42 non-null     object
#  11  Aesthetically good-looking                          47 non-null     object
#  12  Vulnerability to pests                              55 non-null     object
#  13  Vulnerability to damage by wildlife                 53 non-null     object
#  14  Suitable to local biodiversity and pollinators      48 non-null     object
#  15  More amount of fertilizers and pesticide necessary  56 non-null     object
#  16  More amount of water necessary                      57 non-null     object
#  17  Adverse impact to soil health and productivity      54 non-null     object
#  18  Less amount of time and energy necessary            55 non-null     object
#  19  Overall climate suitability                         47 non-null     object
#  20  Initial costliness                                  50 non-null     object
#  21  Economic or market viability/demand                 52 non-null     object
#  22  Less perishable and higher storage life             53 non-null     object
#  23  Crop Choice                                         111 non-null    object
# dtypes: float64(3), object(21)
# memory usage: 21.7+ KB

# %%
#Lets save our combined dataframe into csv for preprocessing and analysis
Crop_decision.to_csv("Master dataframe.csv")
